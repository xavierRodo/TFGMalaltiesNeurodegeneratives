# %%
import pickle
import numpy as np
import pandas as pd
import copy
pd.set_option('display.max_rows', 100)

# %% [markdown]
# # Exploració resultats
#
# ## 2 layer FA & GM

# %%
with open("resultats_two_layer_FA_GM.pkl", "rb") as fp:   # Unpickling
    layer2_FA_GM = pickle.load(fp)

# %% [markdown]
# #### Metric name correction

# %%
for i in range(len(layer2_FA_GM)):
    layer2_FA_GM[i][2]=layer2_FA_GM[i][2].split('.')[1].split(' ')[0]

# %%
#df_layer2_FA_GM = pd.DataFrame(columns=['Single','Partial','All', 'Top Nodes 1', 'Top Nodes 2', 'Top Nodes 3', 'Top Metric'], index=[ind])
#ind2=FA1.index.values
df = pd.DataFrame(layer2_FA_GM, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Matrix','Metric','Groups']).groupby(['Node']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                                  Pvalue
# Node
# ctx.rh.lateralorbitofrontal          11
# ctx.rh.parsopercularis                9
# right.amygdala                        7
# left.amygdala                         6
# ctx.lh.insula                         6
# ctx.rh.lateraloccipital               5
# ctx.rh.precentral                     5
# ctx.rh.medialorbitofrontal            5
# ctx.lh.caudalanteriorcingulate        4
# ctx.rh.parahippocampal                4
# ctx.rh.caudalanteriorcingulate        4
# ctx.rh.cuneus                         4
# ctx.rh.isthmuscingulate               4
# ctx.rh.paracentral                    4
# ctx.rh.posteriorcingulate             4
# ctx.rh.pericalcarine                  4
# ctx.lh.precuneus                      4
# ctx.rh.rostralanteriorcingulate       4
# ctx.rh.superiorfrontal                4
# ctx.rh.superiorparietal               4
# left.putamen                          4
# right.putamen                         4
# ctx.lh.rostralanteriorcingulate       4
# right.thalamus                        4
# ctx.lh.lingual                        4
# ctx.lh.lateraloccipital               4
# ctx.lh.inferiortemporal               4
# ctx.lh.pericalcarine                  4
# ctx.lh.paracentral                    4
# ctx.lh.posteriorcingulate             4
# ctx.lh.isthmuscingulate               4
# ctx.lh.supramarginal                  3
# left.thalamus                         3
# ctx.rh.inferiorparietal               3
# ctx.lh.parahippocampal                3
# ctx.lh.lateralorbitofrontal           3
# ctx.rh.postcentral                    3
# ctx.lh.cuneus                         3
# ctx.rh.superiortemporal               3
# ctx.rh.rostralmiddlefrontal           2
# ctx.rh.supramarginal                  2
# ctx.rh.precuneus                      2
# ctx.lh.precentral                     2
# left.accumbens                        2
# ctx.lh.inferiorparietal               2
# left.pallidum                         2
# ctx.lh.fusiform                       2
# right.accumbens                       2
# ctx.lh.entorhinal                     2
# right.caudate                         2
# right.hippocampus                     2
# right.pallidum                        2
# left.caudate                          2
# ctx.lh.medialorbitofrontal            2
# ctx.lh.rostralmiddlefrontal           2
# ctx.lh.parstriangularis               2
# ctx.lh.superiorfrontal                2
# ctx.lh.superiortemporal               2
# ctx.rh.caudalmiddlefrontal            2
# ctx.lh.postcentral                    2
# ctx.rh.parstriangularis               2
# ctx.lh.caudalmiddlefrontal            2
# ctx.rh.insula                         2
# ctx.lh.parsorbitalis                  2
# ctx.rh.lingual                        2
# ctx.lh.parsopercularis                2
# ctx.rh.middletemporal                 2
# ctx.lh.middletemporal                 2
# ctx.rh.parsorbitalis                  2
# ctx.rh.transversetemporal             1
# ctx.rh.inferiortemporal               1
# ctx.rh.fusiform                       1
# ctx.rh.entorhinal                     1
# ctx.lh.transversetemporal             1
# ctx.lh.superiorparietal               1
# left.hippocampus                      1

# %%
df = pd.DataFrame(layer2_FA_GM, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Matrix','Node','Groups']).groupby(['Metric']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                         Pvalue
# Metric
# clustering                 139
# strenght                    35
# degree                      30
# betweenness_centrality      14
# local_efficiency            12
# clossness_centrality         7

# %%
df = pd.DataFrame(layer2_FA_GM, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Matrix','Node','Metric']).groupby(['Groups']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#            Pvalue
# Groups
# Sans_RRMS     197
# RRMS_PPMS      16
# Sans_PPMS      14
# SPMS_PPMS       9
# Sans_SPMS       1

# %%
df = pd.DataFrame(layer2_FA_GM, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Groups','Node','Metric']).groupby(['Matrix']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#         Pvalue
# Matrix
# FA         138
# GM          99

# %%
df = pd.DataFrame(layer2_FA_GM, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Groups','Metric']).groupby(['Matrix','Node']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                                        Pvalue
# Matrix Node
# GM     ctx.rh.lateralorbitofrontal          7
#        ctx.rh.parsopercularis               6
# FA     ctx.rh.precentral                    4
# GM     right.amygdala                       4
#        left.amygdala                        4
# ...                                       ...
# FA     ctx.lh.caudalmiddlefrontal           1
#        right.thalamus                       1
#        right.pallidum                       1
#        right.hippocampus                    1
# GM     ctx.lh.caudalanteriorcingulate       1
#
# [143 rows x 1 columns]

# %%
df = pd.DataFrame(layer2_FA_GM, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Groups']).groupby(['Matrix','Node','Metric']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                                                            Pvalue
# Matrix Node                        Metric
# GM     ctx.lh.insula               betweenness_centrality       2
#        ctx.rh.parsopercularis      strenght                     2
#        ctx.rh.lateralorbitofrontal local_efficiency             2
#                                    strenght                     2
#        ctx.rh.parsopercularis      clustering                   2
# ...                                                           ...
# FA     ctx.rh.paracentral          degree                       1
#                                    strenght                     1
#        ctx.rh.parahippocampal      clustering                   1
#                                    degree                       1
# GM     right.thalamus              strenght                     1
#
# [231 rows x 1 columns]
