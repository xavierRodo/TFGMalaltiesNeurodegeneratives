# %%
import pickle
import numpy as np
import pandas as pd
import copy
pd.set_option('display.max_rows', 100)

# %% [markdown]
# # Exploració resultats
# ## 3 layer 3 supra connections

# %%
with open("resultats_three_layer_three.pkl", "rb") as fp:   # Unpickling
    mlayer = pickle.load(fp)

# %% [markdown]
# #### Metric name correction

# %%
for i in range(len(mlayer)):
    mlayer[i][2]=mlayer[i][2].split('.')[1].split(' ')[0]

# %%
mlayer=pd.DataFrame(mlayer)
mlayer=mlayer.dropna()
mlayer=mlayer.to_numpy()

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Matrix','Metric','Groups']).groupby(['Node']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                                  Pvalue
# Node
# ctx.rh.lateralorbitofrontal          29
# ctx.lh.inferiortemporal              23
# ctx.rh.transversetemporal            21
# ctx.lh.caudalanteriorcingulate       20
# right.putamen                        20
# left.putamen                         20
# ctx.rh.cuneus                        20
# ctx.lh.parahippocampal               20
# ctx.lh.rostralanteriorcingulate      19
# ctx.rh.parsopercularis               18
# ctx.lh.superiortemporal              18
# ctx.lh.caudalmiddlefrontal           18
# ctx.rh.parahippocampal               18
# ctx.rh.rostralanteriorcingulate      18
# ctx.rh.postcentral                   18
# ctx.rh.precentral                    18
# ctx.rh.superiorfrontal               18
# ctx.rh.superiorparietal              18
# ctx.rh.superiortemporal              18
# left.amygdala                        18
# right.pallidum                       18
# ctx.lh.rostralmiddlefrontal          18
# ...

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Matrix','Node','Groups']).groupby(['Metric']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                         Pvalue
# Metric
# local_efficiency           292
# clossness_centrality       286
# betweenness_centrality     254
# degree                     177
# strenght                   168
# clustering                  68

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Matrix','Node','Metric']).groupby(['Groups']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#            Pvalue
# Groups
# Sans_RRMS     531
# Sans_SPMS     376
# Sans_PPMS     302
# RRMS_PPMS      16
# RRMS_SPMS      10
# SPMS_PPMS      10

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Groups','Node','Metric']).groupby(['Matrix']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#         Pvalue
# Matrix
# GM         938
# FA         296
# RS          11

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Groups','Metric']).groupby(['Matrix','Node']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                                     Pvalue
# Matrix Node
# GM     ctx.rh.lateralorbitofrontal      19
#        right.thalamus                   15
#        ctx.rh.parsopercularis           15
#        ctx.lh.inferiortemporal          15
#        ctx.rh.superiortemporal          14
# ...                                    ...
# RS     ctx.lh.inferiortemporal           1
#        ctx.rh.lingual                    1
# FA     left.thalamus                     1
#        right.accumbens                   1
#        ctx.rh.inferiorparietal           1
#
# [157 rows x 1 columns]

# %%
pd.set_option('display.max_rows', None)
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
#df = df.drop(df[df.Pvalue > 0.001].index)
df = df.groupby(['Matrix','Node','Metric'])#.count().sort_values(by='Pvalue', ascending=False)
#df = df.drop(df[df.Pvalue < 1].index)
df.head(1000)
# Out:
#      Matrix                             Node                  Metric  \
# 0        FA   ctx.lh.caudalanteriorcingulate                  degree
# 1        FA   ctx.lh.caudalanteriorcingulate                  degree
# 2        FA   ctx.lh.caudalanteriorcingulate                  degree
# 3        FA   ctx.lh.caudalanteriorcingulate                  degree
# 4        FA   ctx.lh.caudalanteriorcingulate                  degree
# 5        FA   ctx.lh.caudalanteriorcingulate                  degree
# 6        FA       ctx.lh.caudalmiddlefrontal                  degree
# 7        FA       ctx.lh.caudalmiddlefrontal                  degree
# 8        FA       ctx.lh.caudalmiddlefrontal                  degree
# 9        FA       ctx.lh.caudalmiddlefrontal                  degree
# 10       FA       ctx.lh.caudalmiddlefrontal                  degree
# 11       FA       ctx.lh.caudalmiddlefrontal                  degree
# 12       FA                    ctx.lh.cuneus                  degree
# ...

# %%
pd.set_option('display.max_rows', None)
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df=df[df["Groups"].str.contains("Sans_RRMS")==False]
df=df[df["Groups"].str.contains("Sans_PPMS")==False]
df=df[df["Groups"].str.contains("Sans_SPMS")==False]

df=df[df["Groups"].str.contains("SPMS_PPMS")==False]

df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Groups']).groupby(['Matrix','Node','Metric']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                                                            Pvalue
# Matrix Node                        Metric
# FA     ctx.lh.inferiortemporal     local_efficiency             1
#        ctx.rh.entorhinal           betweenness_centrality       1
# RS     right.putamen               degree                       1
#        left.amygdala               strenght                     1
#                                    degree                       1
#        ctx.rh.transversetemporal   strenght                     1
#                                    degree                       1
#        ctx.rh.lingual              clustering                   1
#        ctx.rh.lateralorbitofrontal local_efficiency             1
#        ctx.lh.inferiortemporal     local_efficiency             1
# GM     right.thalamus              strenght                     1
#                                    degree                       1
#        left.thalamus               degree                       1
# ...

# %%
df.keys()
# Out:
# Index(['Pvalue'], dtype='object')
