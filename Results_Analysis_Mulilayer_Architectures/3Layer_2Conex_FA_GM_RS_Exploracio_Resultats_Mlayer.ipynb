# %%
import pickle
import numpy as np
import pandas as pd
import copy
pd.set_option('display.max_rows', 100)

# %% [markdown]
# # Exploració resultats
#
# ## 3 layer 2 supra connections GM in the middle

# %%
with open("resultats_three_layer_two_FA_GM_RS.pkl", "rb") as fp:   # Unpickling
    mlayer = pickle.load(fp)

# %% [markdown]
# #### Metric name correction

# %%
for i in range(len(mlayer)):
    mlayer[i][2]=mlayer[i][2].split('.')[1].split(' ')[0]

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Matrix','Metric','Groups']).groupby(['Node']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                                  Pvalue
# Node
# ctx.rh.lateralorbitofrontal          16
# right.amygdala                       16
# left.amygdala                        15
# right.putamen                        13
# ctx.rh.medialorbitofrontal           13
# ctx.lh.inferiortemporal              12
# right.thalamus                       12
# ctx.rh.lateraloccipital              12
# ctx.rh.cuneus                        11
# left.thalamus                        11
# ctx.rh.parsopercularis               11
# left.pallidum                        10
# ctx.rh.parahippocampal               10
# ctx.rh.pericalcarine                 10
# ctx.rh.superiorfrontal               10
# left.putamen                         10
# ctx.lh.parahippocampal                9
# ctx.rh.posteriorcingulate             9
# ctx.lh.cuneus                         9
# ctx.rh.entorhinal                     9
# right.pallidum                        9
# ctx.rh.middletemporal                 9
# ctx.rh.paracentral                    9
# ctx.lh.inferiorparietal               9
# ctx.lh.middletemporal                 9
# ctx.rh.rostralanteriorcingulate       9
# ctx.lh.precuneus                      9
# ctx.lh.posteriorcingulate             9
# ctx.rh.superiorparietal               9
# ctx.rh.superiortemporal               9
# ctx.rh.inferiortemporal               9
# left.caudate                          9
# ctx.lh.insula                         9
# left.hippocampus                      8
# ctx.rh.parsorbitalis                  8
# right.hippocampus                     8
# right.caudate                         8
# ctx.lh.caudalanteriorcingulate        8
# ctx.rh.insula                         8
# ctx.lh.superiortemporal               8
# ctx.lh.pericalcarine                  8
# ctx.lh.parstriangularis               8
# ctx.lh.superiorfrontal                8
# ctx.lh.superiorparietal               8
# ctx.lh.paracentral                    8
# ctx.lh.entorhinal                     8
# ctx.rh.fusiform                       8
# ctx.rh.inferiorparietal               8
# ctx.lh.medialorbitofrontal            7
# ctx.rh.rostralmiddlefrontal           7
# ctx.lh.lateralorbitofrontal           7
# ctx.lh.fusiform                       7
# ctx.lh.parsopercularis                7
# ctx.rh.supramarginal                  7
# ctx.rh.isthmuscingulate               7
# ctx.lh.precentral                     7
# ctx.lh.rostralanteriorcingulate       7
# ctx.rh.precentral                     7
# ctx.rh.caudalanteriorcingulate        7
# ctx.rh.precuneus                      7
# ctx.rh.parstriangularis               6
# ctx.rh.lingual                        6
# ctx.lh.isthmuscingulate               6
# ctx.lh.lingual                        6
# ctx.lh.transversetemporal             6
# ctx.lh.supramarginal                  6
# ctx.lh.parsorbitalis                  6
# ctx.rh.transversetemporal             6
# ctx.lh.rostralmiddlefrontal           6
# ctx.lh.postcentral                    6
# ctx.lh.caudalmiddlefrontal            6
# ctx.rh.postcentral                    5
# left.accumbens                        5
# ctx.lh.lateraloccipital               5
# ctx.rh.caudalmiddlefrontal            4
# right.accumbens                       3

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Matrix','Node','Groups']).groupby(['Metric']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                         Pvalue
# Metric
# degree                     177
# strenght                   168
# betweenness_centrality     145
# local_efficiency            72
# clustering                  61
# clossness_centrality        14

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Matrix','Node','Metric']).groupby(['Groups']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#            Pvalue
# Groups
# Sans_RRMS     364
# Sans_SPMS     217
# RRMS_PPMS      19
# Sans_PPMS      15
# SPMS_PPMS      13
# RRMS_SPMS       9

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Groups','Node','Metric']).groupby(['Matrix']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#         Pvalue
# Matrix
# GM         490
# FA         132
# RS          15

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Groups','Metric']).groupby(['Matrix','Node']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                                         Pvalue
# Matrix Node
# GM     right.amygdala                       12
#        right.thalamus                       11
#        ctx.rh.lateralorbitofrontal          11
#        ctx.rh.medialorbitofrontal           10
#        left.amygdala                        10
# ...                                        ...
# RS     ctx.lh.rostralanteriorcingulate       0
#        ctx.lh.precuneus                      0
#        ctx.lh.precentral                     0
#        ctx.lh.posteriorcingulate             0
#        right.thalamus                        0
#
# [218 rows x 1 columns]

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Groups']).groupby(['Matrix','Node','Metric']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                                                                Pvalue
# Matrix Node                            Metric
# GM     ctx.rh.inferiorparietal         betweenness_centrality       3
#        right.thalamus                  strenght                     3
#        left.amygdala                   local_efficiency             3
#                                        degree                       3
#        left.pallidum                   betweenness_centrality       3
# ...                                                               ...
# RS     ctx.lh.rostralanteriorcingulate local_efficiency             0
#                                        degree                       0
#                                        clustering                   0
#                                        clossness_centrality         0
#        right.thalamus                  strenght                     0
#
# [852 rows x 1 columns]
