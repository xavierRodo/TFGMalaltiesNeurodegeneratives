# %%
import pickle
import numpy as np
import pandas as pd
import copy
pd.set_option('display.max_rows', 100)

# %% [markdown]
# # Exploració resultats
#
# ## 2 layer GM & RS

# %%
with open("resultats_two_layer_RS_GM.pkl", "rb") as fp:   # Unpickling
    mlayer = pickle.load(fp)

# %% [markdown]
# #### Metric name correction

# %%
for i in range(len(mlayer)):
    mlayer[i][2]=mlayer[i][2].split('.')[1].split(' ')[0]

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Matrix','Metric','Groups']).groupby(['Node']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                              Pvalue
# Node
# ctx.rh.transversetemporal         8
# ctx.rh.lateralorbitofrontal       8
# left.amygdala                     7
# ctx.rh.parsopercularis            6
# right.amygdala                    5
# right.thalamus                    4
# ctx.rh.fusiform                   3
# ctx.rh.medialorbitofrontal        3
# right.putamen                     2
# right.hippocampus                 2
# ctx.lh.lateraloccipital           2
# ctx.lh.inferiortemporal           2
# ctx.lh.parahippocampal            2
# ctx.rh.parsorbitalis              2
# ctx.rh.middletemporal             1
# ctx.rh.postcentral                1
# ctx.rh.inferiorparietal           1
# ctx.lh.transversetemporal         1
# left.putamen                      1
# left.thalamus                     1
# ctx.lh.parsopercularis            1
# right.pallidum                    1
# ctx.lh.middletemporal             1
# ctx.rh.parahippocampal            0
# left.hippocampus                  0
# left.pallidum                     0
# right.accumbens                   0

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Matrix','Node','Groups']).groupby(['Metric']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                         Pvalue
# Metric
# strenght                    25
# local_efficiency            15
# degree                      10
# betweenness_centrality       8
# clustering                   5
# clossness_centrality         2

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Matrix','Node','Metric']).groupby(['Groups']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#            Pvalue
# Groups
# Sans_PPMS      19
# RRMS_PPMS      15
# SPMS_PPMS      11
# Sans_RRMS      10
# RRMS_SPMS       6
# Sans_SPMS       4

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Groups','Node','Metric']).groupby(['Matrix']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#         Pvalue
# Matrix
# RS          39
# GM          26

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Groups','Metric']).groupby(['Matrix','Node']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                                     Pvalue
# Matrix Node
# RS     ctx.rh.transversetemporal         6
# GM     ctx.rh.lateralorbitofrontal       5
#        ctx.rh.parsopercularis            4
# RS     left.amygdala                     4
#        right.amygdala                    3
#        ctx.rh.lateralorbitofrontal       3
#        ctx.rh.fusiform                   3
# GM     left.amygdala                     3
#        right.thalamus                    2
# RS     ctx.lh.parahippocampal            2
#        ctx.lh.inferiortemporal           2
#        right.thalamus                    2
# GM     right.amygdala                    2
# RS     ctx.rh.parsopercularis            2
# GM     ctx.rh.transversetemporal         2
# RS     right.hippocampus                 2
# GM     ctx.rh.medialorbitofrontal        2
# RS     right.putamen                     2
#        ctx.rh.parsorbitalis              2
#        left.putamen                      1
#        right.pallidum                    1
# GM     ctx.lh.lateraloccipital           1
# RS     ctx.rh.medialorbitofrontal        1
# GM     ctx.lh.middletemporal             1
# RS     ctx.lh.parsopercularis            1
#        ctx.lh.lateraloccipital           1
# GM     left.thalamus                     1
#        ctx.rh.postcentral                1
#        ctx.rh.middletemporal             1
#        ctx.rh.inferiorparietal           1
# RS     ctx.lh.transversetemporal         1
#        ctx.rh.parahippocampal            0
#        left.hippocampus                  0
#        left.pallidum                     0
#        right.accumbens                   0

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Groups']).groupby(['Matrix','Node','Metric']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                                                            Pvalue
# Matrix Node                        Metric
# RS     right.amygdala              strenght                     2
#        right.hippocampus           strenght                     2
#        ctx.rh.transversetemporal   degree                       2
#                                    strenght                     2
#        ctx.rh.parsopercularis      local_efficiency             2
#        left.amygdala               strenght                     2
#        ctx.lh.inferiortemporal     local_efficiency             2
# GM     ctx.rh.parsopercularis      strenght                     2
# RS     ctx.rh.parsorbitalis        strenght                     2
#        ctx.rh.lateralorbitofrontal local_efficiency             2
# GM     ctx.rh.lateralorbitofrontal strenght                     2
#                                    local_efficiency             2
# RS     ctx.lh.parahippocampal      strenght                     2
#        ctx.rh.transversetemporal   clossness_centrality         1
#        ctx.rh.lateralorbitofrontal strenght                     1
#        ctx.rh.fusiform             strenght                     1
# GM     ctx.lh.middletemporal       betweenness_centrality       1
# RS     ctx.rh.fusiform             degree                       1
# GM     ctx.lh.lateraloccipital     betweenness_centrality       1
# RS     left.amygdala               degree                       1
#        ctx.rh.transversetemporal   clustering                   1
#        ctx.lh.transversetemporal   strenght                     1
#        left.amygdala               local_efficiency             1
#        left.putamen                clustering                   1
#        right.amygdala              local_efficiency             1
#        right.pallidum              strenght                     1
#        right.putamen               degree                       1
#                                    strenght                     1
#        right.thalamus              degree                       1
#        ctx.rh.fusiform             betweenness_centrality       1
#        ctx.rh.medialorbitofrontal  local_efficiency             1
#        right.thalamus              strenght                     1
# GM     right.thalamus              degree                       1
#        ctx.rh.transversetemporal   clossness_centrality         1
#                                    clustering                   1
#        left.amygdala               degree                       1
#        ctx.rh.parsopercularis      local_efficiency             1
#                                    clustering                   1
#        left.amygdala               local_efficiency             1
#                                    strenght                     1
#        left.thalamus               degree                       1
#        right.amygdala              local_efficiency             1
#                                    strenght                     1
#        ctx.rh.postcentral          clustering                   1
#        ctx.rh.middletemporal       betweenness_centrality       1
#        ctx.rh.medialorbitofrontal  local_efficiency             1
#        ctx.rh.inferiorparietal     betweenness_centrality       1
# RS     ctx.lh.parsopercularis      betweenness_centrality       1
# GM     ctx.rh.lateralorbitofrontal degree                       1
#        ctx.rh.medialorbitofrontal  betweenness_centrality       1
# RS     ctx.lh.lateraloccipital     betweenness_centrality       1
# GM     right.thalamus              strenght                     1
# RS     right.pallidum              betweenness_centrality       0
#                                    clustering                   0
#                                    degree                       0
#        right.hippocampus           degree                       0
#        right.accumbens             betweenness_centrality       0
#        right.hippocampus           clustering                   0
#        right.amygdala              degree                       0
#                                    clustering                   0
#                                    betweenness_centrality       0
#        right.accumbens             degree                       0
#                                    clustering                   0
#        right.hippocampus           betweenness_centrality       0
#        ctx.lh.transversetemporal   clustering                   0
#        left.putamen                degree                       0
#                                    betweenness_centrality       0
#        ctx.lh.transversetemporal   betweenness_centrality       0
#        ctx.lh.parahippocampal      degree                       0
#                                    clustering                   0
#        ctx.rh.lateralorbitofrontal betweenness_centrality       0
#                                    clustering                   0
#                                    degree                       0
#        ctx.lh.parahippocampal      betweenness_centrality       0
#        ctx.rh.parahippocampal      clustering                   0
#        ctx.rh.parsorbitalis        betweenness_centrality       0
#                                    clustering                   0
#                                    degree                       0
#        left.amygdala               betweenness_centrality       0
#                                    clustering                   0
#        ctx.lh.transversetemporal   degree                       0
#        left.pallidum               betweenness_centrality       0
#                                    clustering                   0
#                                    degree                       0
#        left.hippocampus            clustering                   0
