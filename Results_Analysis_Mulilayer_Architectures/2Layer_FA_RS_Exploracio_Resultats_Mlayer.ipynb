# %%
import pickle
import numpy as np
import pandas as pd
import copy
pd.set_option('display.max_rows', 100)

# %% [markdown]
# # Exploració resultats
#
# ## 2 layer FA & RS

# %%
with open("resultats_two_layer_FA_RS.pkl", "rb") as fp:   # Unpickling
    mlayer = pickle.load(fp)

# %% [markdown]
# #### Metric name correction

# %%
for i in range(len(mlayer)):
    mlayer[i][2]=mlayer[i][2].split('.')[1].split(' ')[0]

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Matrix','Metric','Groups']).groupby(['Node']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                                  Pvalue
# Node
# right.putamen                         7
# ctx.rh.transversetemporal             6
# ctx.lh.insula                         6
# ctx.rh.rostralanteriorcingulate       5
# ctx.rh.posteriorcingulate             5
# ctx.lh.parsorbitalis                  5
# ctx.rh.isthmuscingulate               5
# ctx.lh.paracentral                    5
# ctx.rh.paracentral                    5
# ctx.rh.caudalanteriorcingulate        5
# ctx.lh.inferiortemporal               5
# left.putamen                          5
# ctx.lh.posteriorcingulate             4
# ctx.rh.parahippocampal                4
# ctx.rh.superiorparietal               4
# ctx.rh.lateraloccipital               4
# left.amygdala                         4
# ctx.rh.fusiform                       4
# ctx.lh.caudalanteriorcingulate        4
# ctx.rh.insula                         4
# right.thalamus                        4
# ctx.lh.isthmuscingulate               4
# ctx.lh.parahippocampal                4
# ctx.rh.cuneus                         3
# ctx.lh.cuneus                         3
# right.hippocampus                     3
# right.amygdala                        3
# ctx.rh.superiorfrontal                3
# ctx.rh.precentral                     3
# ctx.rh.pericalcarine                  3
# ctx.lh.pericalcarine                  3
# ctx.lh.lingual                        3
# ctx.rh.parsorbitalis                  3
# ctx.rh.caudalmiddlefrontal            3
# ctx.lh.precuneus                      3
# ctx.lh.rostralanteriorcingulate       3
# ctx.rh.lateralorbitofrontal           2
# ctx.rh.postcentral                    2
# ctx.lh.transversetemporal             2
# ctx.lh.fusiform                       2
# left.thalamus                         2
# left.caudate                          2
# ctx.lh.caudalmiddlefrontal            2
# right.pallidum                        2
# ctx.rh.entorhinal                     2
# right.accumbens                       1
# left.pallidum                         1
# ctx.rh.rostralmiddlefrontal           1
# left.accumbens                        1
# ctx.lh.inferiorparietal               1
# ctx.rh.supramarginal                  1
# ctx.rh.superiortemporal               1
# ctx.lh.precentral                     1
# ctx.lh.rostralmiddlefrontal           1
# ctx.lh.superiorfrontal                1
# ctx.rh.precuneus                      1
# ctx.lh.lateraloccipital               1
# ctx.rh.middletemporal                 1
# ctx.lh.parsopercularis                1
# ctx.rh.inferiorparietal               1
# ctx.lh.middletemporal                 1
# ctx.rh.lingual                        1
# ctx.lh.superiorparietal               1
# ctx.lh.postcentral                    1
# ctx.lh.medialorbitofrontal            1
# ctx.rh.parsopercularis                1
# ctx.lh.supramarginal                  1
# ctx.lh.superiortemporal               1
# ctx.lh.lateralorbitofrontal           1
# left.hippocampus                      0
# ctx.lh.entorhinal                     0
# ctx.rh.parstriangularis               0
# ctx.lh.parstriangularis               0
# right.caudate                         0
# ctx.rh.inferiortemporal               0
# ctx.rh.medialorbitofrontal            0

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Matrix','Node','Groups']).groupby(['Metric']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                         Pvalue
# Metric
# clustering                  66
# strenght                    46
# local_efficiency            38
# degree                      32
# betweenness_centrality       7

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Matrix','Node','Metric']).groupby(['Groups']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#            Pvalue
# Groups
# Sans_RRMS     164
# Sans_PPMS      12
# RRMS_SPMS       9
# Sans_SPMS       4
# RRMS_PPMS       0
# SPMS_PPMS       0

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Groups','Node','Metric']).groupby(['Matrix']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#         Pvalue
# Matrix
# FA         138
# RS          51

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Groups','Metric']).groupby(['Matrix','Node']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                                        Pvalue
# Matrix Node
# RS     ctx.rh.transversetemporal            6
# FA     ctx.lh.insula                        5
#        ctx.lh.caudalanteriorcingulate       4
#        ctx.rh.caudalanteriorcingulate       4
# RS     left.amygdala                        4
# ...                                       ...
#        ctx.rh.parahippocampal               0
#        ctx.rh.parstriangularis              0
#        ctx.rh.pericalcarine                 0
#        ctx.lh.superiortemporal              0
#        ctx.lh.middletemporal                0
#
# [126 rows x 1 columns]

# %%
df = pd.DataFrame(mlayer, columns=['Matrix','Node','Metric','Groups','Pvalue'])
df = df.drop(df[df.Pvalue > 0.001].index)
df = df.drop(columns=['Groups']).groupby(['Matrix','Node','Metric']).count().sort_values(by='Pvalue', ascending=False)
df
# Out:
#                                                         Pvalue
# Matrix Node                           Metric
# RS     ctx.rh.transversetemporal      strenght               2
#        ctx.rh.parsorbitalis           strenght               2
#        right.hippocampus              strenght               2
#        right.amygdala                 strenght               2
#        ctx.lh.parsorbitalis           local_efficiency       2
# ...                                                        ...
#        ctx.rh.inferiortemporal        clustering             0
#        ctx.rh.inferiorparietal        clustering             0
#        ctx.rh.entorhinal              clustering             0
#        ctx.lh.transversetemporal      degree                 0
#        ctx.rh.caudalanteriorcingulate clustering             0
#
# [249 rows x 1 columns]
